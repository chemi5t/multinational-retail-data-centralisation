# %%
import pandas as pd
from dateutil.parser import parse # to help with datatime edits

# Import data from 'products_details.csv' into DataFrame.
table_name = 'products_details'
csv_file_path = 'products_details.csv'
products_details_df = pd.read_csv(csv_file_path, index_col=0)
# Display the DataFrame
display(products_details_df)
# Out:
#                                      product_name product_price  weight  \
# 0     FurReal Dazzlin' Dimples My Playful Dolphin        £39.99   1.6kg
# 1             Tiffany's World Day Out At The Park        £12.99  0.48kg
# 2             Tiffany's World Pups Picnic Playset         £7.00    590g
# 3        Tiffany's World Wildlife Park Adventures        £12.99    540g
# 4                         Cosatto Cosy Dolls Pram        £30.00  1.91kg
# ...                                           ...           ...     ...
# 1848    Goodmans Qi Autosense In Car Phone Holder        £15.00    125g
# 1849    Goodmans Qi Wireless Charging Phone Stand        £15.00    134g
# 1850                     RAC 12V Wet & Dry Vacuum        £18.00    820g
# 1851    Goodmans Qi Autosense In Car Phone Holder        £15.00    125g
# 1852               Beldray Telescopic Ladder 2.9m        £69.00   9.4kg
#
#             category            EAN  date_added  \
# 0     toys-and-games  7425710935115  2005-12-02
# ...

# %%
products_details_df_original = products_details_df.copy()

display(products_details_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1853 entries, 0 to 1852
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   1849 non-null   object
#  1   product_price  1849 non-null   object
#  2   weight         1849 non-null   object
#  3   category       1849 non-null   object
#  4   EAN            1849 non-null   object
#  5   date_added     1849 non-null   object
#  6   uuid           1849 non-null   object
#  7   removed        1849 non-null   object
#  8   product_code   1849 non-null   object
# dtypes: object(9)
# memory usage: 144.8+ KB
# None

# %% [markdown]
# # null

# %%
# Show rows where 'product_price' values isnull
filtered_products_details_df = products_details_df[products_details_df['product_price'].isnull()]

display(filtered_products_details_df.info())
display(filtered_products_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 266 to 1660
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   0 non-null      object
#  1   product_price  0 non-null      object
#  2   weight         0 non-null      object
#  3   category       0 non-null      object
#  4   EAN            0 non-null      object
#  5   date_added     0 non-null      object
#  6   uuid           0 non-null      object
#  7   removed        0 non-null      object
#  8   product_code   0 non-null      object
# dtypes: object(9)
# memory usage: 320.0+ bytes
# None
#      product_name product_price weight category  EAN date_added uuid removed  \
# 266           NaN           NaN    NaN      NaN  NaN        NaN  NaN     NaN
# 788           NaN           NaN    NaN      NaN  NaN        NaN  NaN     NaN
# 794           NaN           NaN    NaN      NaN  NaN        NaN  NaN     NaN
# ...

# %%
# Show rows where 'product_price' values are notnull
filtered_products_details_df = products_details_df[products_details_df['product_price'].notnull()]

display(filtered_products_details_df.info())
display(filtered_products_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1849 entries, 0 to 1852
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   1849 non-null   object
#  1   product_price  1849 non-null   object
#  2   weight         1849 non-null   object
#  3   category       1849 non-null   object
#  4   EAN            1849 non-null   object
#  5   date_added     1849 non-null   object
#  6   uuid           1849 non-null   object
#  7   removed        1849 non-null   object
#  8   product_code   1849 non-null   object
# dtypes: object(9)
# memory usage: 144.5+ KB
# None
#                                      product_name product_price  weight  \
# 0     FurReal Dazzlin' Dimples My Playful Dolphin        £39.99   1.6kg
# 1             Tiffany's World Day Out At The Park        £12.99  0.48kg
# 2             Tiffany's World Pups Picnic Playset         £7.00    590g
# ...

# %% [markdown]
# # category

# %%
print(filtered_products_details_df['category'].unique())
print(filtered_products_details_df['category'].nunique(), "\n")
# Out:
# ['toys-and-games' 'sports-and-leisure' 'pets' 'homeware' 'S1YB74MLMJ'
#  'C3NCA2CL35' 'WVPMHZP59U' 'health-and-beauty' 'food-and-drink' 'diy']
# 10

# %%
# regular expression to filter out rows where 'category' contains numbers
filtered_products_details_df = filtered_products_details_df[~filtered_products_details_df['category'].str.contains('\d')]

# Display unique values and count after filtering
print(filtered_products_details_df['category'].unique())
print(filtered_products_details_df['category'].nunique())

# Display the updated DataFrame
display(filtered_products_details_df)
display(filtered_products_details_df.info())
# Out:
# ['toys-and-games' 'sports-and-leisure' 'pets' 'homeware'
#  'health-and-beauty' 'food-and-drink' 'diy']
# 7
#                                      product_name product_price  weight  \
# 0     FurReal Dazzlin' Dimples My Playful Dolphin        £39.99   1.6kg
# 1             Tiffany's World Day Out At The Park        £12.99  0.48kg
# 2             Tiffany's World Pups Picnic Playset         £7.00    590g
# 3        Tiffany's World Wildlife Park Adventures        £12.99    540g
# 4                         Cosatto Cosy Dolls Pram        £30.00  1.91kg
# ...                                           ...           ...     ...
# 1848    Goodmans Qi Autosense In Car Phone Holder        £15.00    125g
# 1849    Goodmans Qi Wireless Charging Phone Stand        £15.00    134g
# 1850                     RAC 12V Wet & Dry Vacuum        £18.00    820g
# 1851    Goodmans Qi Autosense In Car Phone Holder        £15.00    125g
# ...

# %%
filtered_products_details_df['category'] = filtered_products_details_df['category'].astype('category')
display(filtered_products_details_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1846 entries, 0 to 1852
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   1846 non-null   object
#  1   product_price  1846 non-null   object
#  2   weight         1846 non-null   object
#  3   category       1846 non-null   category
#  4   EAN            1846 non-null   object
#  5   date_added     1846 non-null   object
#  6   uuid           1846 non-null   object
#  7   removed        1846 non-null   object
#  8   product_code   1846 non-null   object
# dtypes: category(1), object(8)
# memory usage: 131.9+ KB
# None

# %% [markdown]
# # date_added

# %%
# def convert_date(date_str):
#     try:
#         return parse(date_str).strftime('%Y-%m-%d')
#     except Exception:
#         return pd.NaT  # Return a pandas NaT for values that cannot be parsed


# filtered_products_details_df['date_added'] = filtered_products_details_df['date_added'].apply(lambda x: convert_date(str(x)) if pd.notnull(x) else x)

# display(filtered_products_details_df.info())
# display(filtered_products_details_df)

# %%
# Show rows where 'latitude' values are notnull
null_check_products_details_df = filtered_products_details_df[filtered_products_details_df['date_added'].isnull()]

display(null_check_products_details_df.info())
display(null_check_products_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   0 non-null      object
#  1   product_price  0 non-null      object
#  2   weight         0 non-null      object
#  3   category       0 non-null      category
#  4   EAN            0 non-null      object
#  5   date_added     0 non-null      object
#  6   uuid           0 non-null      object
#  7   removed        0 non-null      object
#  8   product_code   0 non-null      object
# dtypes: category(1), object(8)
# memory usage: 356.0+ bytes
# None
# Empty DataFrame
# Columns: [product_name, product_price, weight, category, EAN, date_added, uuid, removed, product_code]
# Index: []

# %%
# Convert the 'date_added' column to datetime format
filtered_products_details_df['date_added'] = filtered_products_details_df['date_added'].apply(parse)
display(filtered_products_details_df.info())
display(filtered_products_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1846 entries, 0 to 1852
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   1846 non-null   object
#  1   product_price  1846 non-null   object
#  2   weight         1846 non-null   object
#  3   category       1846 non-null   category
#  4   EAN            1846 non-null   object
#  5   date_added     1846 non-null   datetime64[ns]
#  6   uuid           1846 non-null   object
#  7   removed        1846 non-null   object
#  8   product_code   1846 non-null   object
# dtypes: category(1), datetime64[ns](1), object(7)
# memory usage: 131.9+ KB
# None
#                                      product_name product_price  weight  \
# 0     FurReal Dazzlin' Dimples My Playful Dolphin        £39.99   1.6kg
# 1             Tiffany's World Day Out At The Park        £12.99  0.48kg
# 2             Tiffany's World Pups Picnic Playset         £7.00    590g
# ...

# %%
print("Display unique values and count after filtering")
print(filtered_products_details_df['date_added'].unique(), "\n")


print("Display the updated DataFrame")
display(filtered_products_details_df)
display(filtered_products_details_df.info())
display(filtered_products_details_df.describe())
# Out:
# Display unique values and count after filtering
# <DatetimeArray>
# ['2005-12-02 00:00:00', '2006-01-09 00:00:00', '1997-03-29 00:00:00',
#  '2013-03-20 00:00:00', '2007-12-23 00:00:00', '2007-02-07 00:00:00',
#  '2009-01-24 00:00:00', '2013-08-13 00:00:00', '2005-05-26 00:00:00',
#  '2003-08-05 00:00:00',
#  ...
#  '1995-04-08 00:00:00', '2016-11-06 00:00:00', '2002-08-29 00:00:00',
#  '1995-12-12 00:00:00', '2014-06-30 00:00:00', '2003-03-09 00:00:00',
#  '2020-08-28 00:00:00', '2012-05-20 00:00:00', '1993-11-28 00:00:00',
#  '2006-10-07 00:00:00']
# Length: 1700, dtype: datetime64[ns]
#
# Display the updated DataFrame
#                                      product_name product_price  weight  \
# 0     FurReal Dazzlin' Dimples My Playful Dolphin        £39.99   1.6kg
# 1             Tiffany's World Day Out At The Park        £12.99  0.48kg
# 2             Tiffany's World Pups Picnic Playset         £7.00    590g
# ...

# %%
# Convert the 'date_added' column to datetime format, handling specific formats
# filtered_products_details_df['date_added'] = pd.to_datetime(filtered_products_details_df['date_added'], errors='coerce', format='%Y-%m-%d')

filtered_products_details_df['date_added'] = filtered_products_details_df['date_added'].combine_first(pd.to_datetime(filtered_products_details_df['date_added'], errors='coerce', format='%Y %B %d'))

# filtered_store_details_df['opening_date'] = filtered_store_details_df['opening_date'].dt.strftime('%Y-%m-%d')
print(filtered_products_details_df['date_added'].unique())

display(filtered_products_details_df)
display(filtered_products_details_df.info())
# Out:
# <DatetimeArray>
# ['2005-12-02 00:00:00', '2006-01-09 00:00:00', '1997-03-29 00:00:00',
#  '2013-03-20 00:00:00', '2007-12-23 00:00:00', '2007-02-07 00:00:00',
#  '2009-01-24 00:00:00', '2013-08-13 00:00:00', '2005-05-26 00:00:00',
#  '2003-08-05 00:00:00',
#  ...
#  '1995-04-08 00:00:00', '2016-11-06 00:00:00', '2002-08-29 00:00:00',
#  '1995-12-12 00:00:00', '2014-06-30 00:00:00', '2003-03-09 00:00:00',
#  '2020-08-28 00:00:00', '2012-05-20 00:00:00', '1993-11-28 00:00:00',
#  '2006-10-07 00:00:00']
# Length: 1700, dtype: datetime64[ns]
#                                      product_name product_price  weight  \
# 0     FurReal Dazzlin' Dimples My Playful Dolphin        £39.99   1.6kg
# 1             Tiffany's World Day Out At The Park        £12.99  0.48kg
# 2             Tiffany's World Pups Picnic Playset         £7.00    590g
# 3        Tiffany's World Wildlife Park Adventures        £12.99    540g
# 4                         Cosatto Cosy Dolls Pram        £30.00  1.91kg
# ...

# %% [markdown]
# # removed

# %%
print("Display unique values and count after filtering")
print(filtered_products_details_df['removed'].unique(), "\n")

print("Display the updated DataFrame")
display(filtered_products_details_df)
display(filtered_products_details_df.info())
# Out:
# Display unique values and count after filtering
# ['Still_avaliable' 'Removed']
#
# Display the updated DataFrame
#                                      product_name product_price  weight  \
# 0     FurReal Dazzlin' Dimples My Playful Dolphin        £39.99   1.6kg
# 1             Tiffany's World Day Out At The Park        £12.99  0.48kg
# 2             Tiffany's World Pups Picnic Playset         £7.00    590g
# 3        Tiffany's World Wildlife Park Adventures        £12.99    540g
# 4                         Cosatto Cosy Dolls Pram        £30.00  1.91kg
# ...                                           ...           ...     ...
# 1848    Goodmans Qi Autosense In Car Phone Holder        £15.00    125g
# 1849    Goodmans Qi Wireless Charging Phone Stand        £15.00    134g
# 1850                     RAC 12V Wet & Dry Vacuum        £18.00    820g
# 1851    Goodmans Qi Autosense In Car Phone Holder        £15.00    125g
# ...

# %%
print("Display unique values and count after filtering")
print(filtered_products_details_df['removed'].unique(), "\n")

print("Display the updated DataFrame")
display(filtered_products_details_df.info())
# Out:
# Display unique values and count after filtering
# ['Still_avaliable' 'Removed']
#
# Display the updated DataFrame
# <class 'pandas.core.frame.DataFrame'>
# Index: 1846 entries, 0 to 1852
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   1846 non-null   object
#  1   product_price  1846 non-null   object
#  2   weight         1846 non-null   object
#  3   category       1846 non-null   category
#  4   EAN            1846 non-null   object
#  5   date_added     1846 non-null   datetime64[ns]
#  6   uuid           1846 non-null   object
#  7   removed        1846 non-null   object
#  8   product_code   1846 non-null   object
# dtypes: category(1), datetime64[ns](1), object(7)
# memory usage: 196.5+ KB
# None

# %%
filtered_products_details_df['removed'] = filtered_products_details_df['removed'].astype('category')
display(filtered_products_details_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1846 entries, 0 to 1852
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   1846 non-null   object
#  1   product_price  1846 non-null   object
#  2   weight         1846 non-null   object
#  3   category       1846 non-null   category
#  4   EAN            1846 non-null   object
#  5   date_added     1846 non-null   datetime64[ns]
#  6   uuid           1846 non-null   object
#  7   removed        1846 non-null   category
#  8   product_code   1846 non-null   object
# dtypes: category(2), datetime64[ns](1), object(6)
# memory usage: 184.0+ KB
# None

# %% [markdown]
# # weight

# %%
print("Display unique values and count after filtering")
print(filtered_products_details_df['weight'].unique(), "\n")
print(filtered_products_details_df['weight'].nunique(), "\n")
# Out:
# Display unique values and count after filtering
# ['1.6kg' '0.48kg' '590g' '540g' '1.91kg' '0.91kg' '0.46kg' '0.38kg'
#  '8.981kg' '1.478kg' '1.2g' '0.66kg' '1.8kg' '1.9kg' '1.725kg' '0.54kg'
#  '0.322kg' '0.71kg' '0.88kg' '0.67kg' '11.076kg' '4kg' '0.385kg' '1.38kg'
#  '2.57kg' '1.35kg' '0.695kg' '1.15kg' '0.98kg' '1.447kg' '1.3625kg'
#  '2.25kg' '0.79kg' '0.8kg' '1.08kg' '2.476kg' '0.137kg' '11.5kg' '0.44kg'
#  '2.75kg' '0.911kg' '0.33kg' '1kg' '0.5kg' '0.45kg' '0.7kg' '0.41kg'
#  '1.3kg' '2kg' '0.34kg' '0.37kg' '0.76kg' '1.18kg' '0.685kg' '1.59kg'
#  '1.4kg' '1.66kg' '13.5kg' '0.745kg' '1.44kg' '0.74kg' '0.660kg' '0.419kg'
#  '0.418kg' '0.470kg' '0.353kg' '0.350kg' '0.96kg' '1.20kg' '1.21kg'
#  '1.02kg' '0.365kg' '0.677kg' '0.55kg' '0.43kg' '0.11kg' '1.23kg' '1.03kg'
#  '0.87kg' '0.39kg' '0.35kg' '0.42kg' '0.27kg' '726g' '0.61kg' '0.864kg'
#  '0.667kg' '0.63kg' '0.72kg' '0.58kg' '0.627kg' '0.3kg' '0.32kg' '0.01kg'
# ...

# %%
import pandas as pd
import numpy as np
import re

class DataCleaning:
    @staticmethod
    def convert_product_weights(df):
        def convert_weight(value):
            try:
                # Check if the value contains 'x' indicating a multiplication
                if 'x' in value:
                    # Extract numeric parts and units from both sides of 'x'
                    numeric_part1, units1, numeric_part2, units2 = re.match(r"([\d.]+)\s*([a-zA-Z]*)\s*x\s*([\d.]+)\s*([a-zA-Z]*)", value).groups()

                    # If units1 is empty, use units2
                    if not units1:
                        units1 = units2

                    # Multiply numeric parts together
                    result = float(numeric_part1) * float(numeric_part2)

                    # Handle units conversion for both parts
                    if units1.lower() in ['g', 'gram', 'grams']:
                        result /= 1000
                    elif units1.lower() in ['ml', 'milliliter', 'milliliters']:
                        result /= 1000
                    elif units1.lower() in ['kg', 'kilogram', 'kilograms']:
                        pass  # No conversion needed for kg
                    elif units1.lower() in ['oz', 'ounce', 'ounces']:
                        result *= 0.0283495
                    else:
                        # If units are not recognized, return NaN
                        return np.nan

                else:
                    # Extract numeric part and units from the value
                    numeric_part, units = re.match(r"([\d.]+)\s*([a-zA-Z]*)", value).groups()

                    # Multiply numeric part by the units
                    result = float(numeric_part)

                    # Handle units conversion
                    if units.lower() in ['g', 'gram', 'grams']:
                        result /= 1000
                    elif units.lower() in ['ml', 'milliliter', 'milliliters']:
                        result /= 1000
                    elif units.lower() in ['kg', 'kilogram', 'kilograms']:
                        pass  # No conversion needed for kg
                    elif units.lower() in ['oz', 'ounce', 'ounces']:
                        result *= 0.0283495
                    else:
                        # If units are not recognized, return NaN
                        return np.nan

                return result

            except Exception as e:
                # If any error occurs, return NaN
                return np.nan

        # Apply the conversion function to the 'weight' column
        df['weight'] = df['weight'].apply(convert_weight)
        # Assuming your DataFrame is named filtered_products_details_df
        df = df.rename(columns={'weight': 'weight (kg)'})


        return round(df, 3)

filtered_products_details_df = DataCleaning.convert_product_weights(filtered_products_details_df)
display(filtered_products_details_df)
display(filtered_products_details_df.info())
# Out:
#                                      product_name product_price  weight (kg)  \
# 0     FurReal Dazzlin' Dimples My Playful Dolphin        £39.99        1.600
# 1             Tiffany's World Day Out At The Park        £12.99        0.480
# 2             Tiffany's World Pups Picnic Playset         £7.00        0.590
# 3        Tiffany's World Wildlife Park Adventures        £12.99        0.540
# 4                         Cosatto Cosy Dolls Pram        £30.00        1.910
# ...                                           ...           ...          ...
# 1848    Goodmans Qi Autosense In Car Phone Holder        £15.00        0.125
# 1849    Goodmans Qi Wireless Charging Phone Stand        £15.00        0.134
# 1850                     RAC 12V Wet & Dry Vacuum        £18.00        0.820
# 1851    Goodmans Qi Autosense In Car Phone Holder        £15.00        0.125
# 1852               Beldray Telescopic Ladder 2.9m        £69.00        9.400
#
# ...

# %%
# Sample DataFrame with test cases
data = {'weight': ['6 x 6g', '6g x 6', '3 x 12kg', '2 x 4oz']}
test_df = pd.DataFrame(data)

# Apply the conversion method
test_df_result = DataCleaning.convert_product_weights(test_df)

# Display the results
display(test_df_result[['weight (kg)']])
# Out:
#    weight (kg)
# 0        0.036
# 1        0.036
# 2       36.000
# 3        0.227

# %%
# Assuming your DataFrame is named filtered_products_details_df
rows_to_view = filtered_products_details_df.iloc[1668:1679]
display(rows_to_view)
# Out:
#                                    product_name product_price  weight (kg)  \
# 1675                     Kenco Rich Coffee 200g         £5.00        0.200
# 1676  Nescafe Dolce Gusto - Latte Machiato 16pk         £3.69        0.160
# 1677      Nescafe Dolce Gusto - Flat White 16pk         £3.69        0.160
# 1678    Kenco Millicano Americano Original 170g         £5.49        0.170
# 1679       Hot Chocolate Christmas Crackers 7pk         £4.00        0.105
# 1680           Nescafe Original Extraforte 230g         £3.29        0.230
# 1681         L'Or Classique Instant Coffee 165g         £4.79        0.165
# 1682        Nescafe Azera Americano Coffee 100g         £3.29        0.100
# 1683                     Kenco Rich Coffee 200g         £5.00        0.200
# 1684      Paxo Turkey & Bacon Stuffing Mix 170g         £1.49        0.170
# 1685        Paxo Sage & Onion Stuffing Mix 340g         £2.69        0.340
#
#             category            EAN date_added  \
# ...

# %%
print(filtered_products_details_df.shape)
# Out:
# (1846, 9)
