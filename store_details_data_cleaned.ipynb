# %%
import pandas as pd

from dateutil.parser import parse # to help with datatime edits

# Import data from 'store_details.csv' into DataFrame.
table_name = 'store_details'
csv_file_path = 'store_details.csv'
store_details_df = pd.read_csv(csv_file_path)
# Display the DataFrame
display(store_details_df)
# Out:
#      index                                            address   longitude  \
# 0        0                                                NaN         NaN
# 1        1  Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, ...    51.62907
# 2        2        Heckerstraße 4/5\n50491 Säckingen, Landshut    48.52961
# 3        3  5 Harrison tunnel\nSouth Lydia\nWC9 2BE, Westbury       51.26
# 4        4  Studio 6\nStephen landing\nSouth Simon\nB77 2W...     53.0233
# ..     ...                                                ...         ...
# 446    446    Täschestraße 25\n39039 Nördlingen, Kirchlengern        52.2
# 447    447                                         K0ODETRLS3  K8CXLZDP07
# 448    448  Studio 8\nMoss mall\nWest Linda\nM0E 6XR, High...    51.62907
# 449    449               Baumplatz 6\n80114 Kötzting, Bretten    49.03685
# 450    450  Gotthilf-Rose-Straße 7/3\n45457 Feuchtwangen, ...    50.64336
#
#             lat      locality    store_code staff_numbers opening_date  \
# ...

# %%
store_details_original = store_details_df.copy()

display(store_details_df.info())
display(store_details_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          451 non-null    int64
#  1   address        447 non-null    object
#  2   longitude      447 non-null    object
#  3   lat            7 non-null      object
#  4   locality       447 non-null    object
#  5   store_code     448 non-null    object
#  6   staff_numbers  448 non-null    object
#  7   opening_date   448 non-null    object
#  8   store_type     448 non-null    object
#  9   latitude       447 non-null    object
#  10  country_code   448 non-null    object
#  11  continent      448 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 42.4+ KB
# None
#             index
# count  451.000000
# mean   225.000000
# std    130.336743
# min      0.000000
# 25%    112.500000
# 50%    225.000000
# 75%    337.500000
# max    450.000000

# %%
# Filter and include rows where 'lat' values are isnull
store_details_df_filtered = store_details_df[store_details_df['lat'].isnull()]

store_details_df_filtered = store_details_df_filtered.drop('lat', axis=1)

            # # Filter and exclude rows where 'longitude' values are isnull i.e. we want notnull rows
            # store_details_df_filtered = store_details_df_filtered[store_details_df_filtered['longitude'].notnull()]

# Filter and exclude rows where 'store_code' values are isnull i.e. we want notnull rows
store_details_df_filtered = store_details_df_filtered[store_details_df_filtered['store_code'].notnull()]

# Filter out letters from the 'staff_numbers'
store_details_df_filtered['staff_numbers'] = store_details_df_filtered['staff_numbers'].str.replace(r'[^0-9]', '', regex=True)
store_details_df_filtered['staff_numbers'] = store_details_df_filtered['staff_numbers'].astype('int64')

# Change datatype
store_details_df_filtered['store_type'] = store_details_df_filtered['store_type'].astype('category')
store_details_df_filtered['store_code'] = store_details_df_filtered['store_code'].astype('string')
store_details_df_filtered['country_code'] = store_details_df_filtered['country_code'].astype('category')

# Replace 'eeEurope': 'Europe', 'eeAmerica': 'America'
store_details_df_filtered['continent'] = store_details_df_filtered['continent'].replace({'eeEurope': 'Europe', 'eeAmerica': 'America'})
store_details_df_filtered['continent'] = store_details_df_filtered['continent'].astype('category')

# Change datatype to string
store_details_df_filtered['address'] = store_details_df_filtered['address'].astype('string')
store_details_df_filtered['locality'] = store_details_df_filtered['locality'].astype('string')

# Convert the 'opening_date' column to datetime format
store_details_df_filtered['opening_date'] = store_details_df_filtered['opening_date'].apply(parse)
# To handle specific formats
# store_details_df_filtered['opening_date'] = store_details_df_filtered['opening_date'].combine_first(pd.to_datetime(store_details_df_filtered['opening_date'], errors='coerce', format='%Y %B %d'))
store_details_df_filtered['opening_date'] = store_details_df_filtered['opening_date'].combine_first(pd.to_datetime(store_details_df_filtered['opening_date'], errors='coerce', format='mixed'))

# Convert 'expiry_date' to datetime format
# store_details_df_filtered['opening_date'] = pd.to_datetime(store_details_df_filtered['opening_date'], format='%y-%m-%d', errors='coerce')
store_details_df_filtered['opening_date'] = pd.to_datetime(store_details_df_filtered['opening_date'], format='mixed', errors='coerce')

print(store_details_df_filtered.isnull().sum())
display(store_details_df_filtered.info())
display(store_details_df_filtered)
# Out:
# index            0
# address          1
# longitude        1
# locality         1
# store_code       0
# staff_numbers    0
# opening_date     0
# store_type       0
# latitude         1
# country_code     0
# continent        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 441 entries, 0 to 450
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          441 non-null    int64
#  1   address        440 non-null    string
#  2   longitude      440 non-null    object
#  3   locality       440 non-null    string
#  4   store_code     441 non-null    string
#  5   staff_numbers  441 non-null    int64
#  6   opening_date   441 non-null    datetime64[ns]
#  7   store_type     441 non-null    category
#  8   latitude       440 non-null    object
#  9   country_code   441 non-null    category
#  10  continent      441 non-null    category
# ...

# %% [markdown]
# # Testing a clenaing method

# %%
# # Filter and include rows where 'lat' values are isnull
# filtered_store_details_df = store_details_df[store_details_df['lat'].isnull()]

# filtered_store_details_df = filtered_store_details_df.drop('lat', axis=1)

#             # # Filter and exclude rows where 'longitude' values are isnull i.e. we want notnull rows
#             # filtered_store_details_df = filtered_store_details_df[filtered_store_details_df['longitude'].notnull()]

# # Filter and exclude rows where 'store_code' values are isnull i.e. we want notnull rows
# filtered_store_details_df = filtered_store_details_df[filtered_store_details_df['store_code'].notnull()]

# # Filter out letters from the 'staff_numbers'
# filtered_store_details_df['staff_numbers'] = filtered_store_details_df['staff_numbers'].str.replace(r'[^0-9]', '', regex=True)
# filtered_store_details_df['staff_numbers'] = filtered_store_details_df['staff_numbers'].astype('int64')

# # Change datatype to category
# filtered_store_details_df['store_type'] = filtered_store_details_df['store_type'].astype('category')

# # Change datatype to string
# filtered_store_details_df['store_code'] = filtered_store_details_df['store_code'].astype('string')

# # Change datatype to category
# filtered_store_details_df['country_code'] = filtered_store_details_df['country_code'].astype('category')

# # Replace 'eeEurope': 'Europe', 'eeAmerica': 'America'
# filtered_store_details_df['continent'] = filtered_store_details_df['continent'].replace({'eeEurope': 'Europe', 'eeAmerica': 'America'})
# filtered_store_details_df['continent'] = filtered_store_details_df['continent'].astype('category')

# # Change datatype to string
# filtered_store_details_df['address'] = filtered_store_details_df['address'].astype('string')

# # Change datatype to string
# filtered_store_details_df['locality'] = filtered_store_details_df['locality'].astype('string')

# # Convert the 'opening_date' column to datetime format
# filtered_store_details_df['opening_date'] = filtered_store_details_df['opening_date'].apply(parse)
# # To handle specific formats
# filtered_store_details_df['opening_date'] = filtered_store_details_df['opening_date'].combine_first(pd.to_datetime(filtered_store_details_df['opening_date'], errors='coerce', format='%Y %B %d'))
# # Convert 'expiry_date' to datetime format
# filtered_store_details_df['opening_date'] = pd.to_datetime(filtered_store_details_df['opening_date'], format='%y-%m-%d', errors='coerce')

# display(filtered_store_details_df.info())
# display(filtered_store_details_df)

# %%
# Show rows where 'latitude' values are notnull
filtered_store_details_df = store_details_df[store_details_df['lat'].notnull()]

display(filtered_store_details_df.info())
display(filtered_store_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 63 to 447
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          7 non-null      int64
#  1   address        7 non-null      object
#  2   longitude      7 non-null      object
#  3   lat            7 non-null      object
#  4   locality       7 non-null      object
#  5   store_code     7 non-null      object
#  6   staff_numbers  7 non-null      object
#  7   opening_date   7 non-null      object
#  8   store_type     7 non-null      object
#  9   latitude       7 non-null      object
#  10  country_code   7 non-null      object
#  11  continent      7 non-null      object
# dtypes: int64(1), object(11)
# memory usage: 728.0+ bytes
# None
#      index     address   longitude         lat    locality  store_code  \
# 63      63  6FWDZHD7PW  1ZVU03X2P6  13KJZ890JH  9IBH8Y4Z0S  NRQKZWJ9OZ
# ...

# %%
# Filter and include rows where 'lat' values are isnull
filtered_store_details_df = store_details_df[store_details_df['lat'].isnull()]

display(filtered_store_details_df.info())
display(filtered_store_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 444 entries, 0 to 450
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          444 non-null    int64
#  1   address        440 non-null    object
#  2   longitude      440 non-null    object
#  3   lat            0 non-null      object
#  4   locality       440 non-null    object
#  5   store_code     441 non-null    object
#  6   staff_numbers  441 non-null    object
#  7   opening_date   441 non-null    object
#  8   store_type     441 non-null    object
#  9   latitude       440 non-null    object
#  10  country_code   441 non-null    object
#  11  continent      441 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 45.1+ KB
# None
#      index                                            address longitude  lat  \
# 0        0                                                NaN       NaN  NaN
# ...

# %%
filtered_store_details_df = filtered_store_details_df.drop('lat', axis=1)

display(filtered_store_details_df.info())
display(filtered_store_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 444 entries, 0 to 450
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          444 non-null    int64
#  1   address        440 non-null    object
#  2   longitude      440 non-null    object
#  3   locality       440 non-null    object
#  4   store_code     441 non-null    object
#  5   staff_numbers  441 non-null    object
#  6   opening_date   441 non-null    object
#  7   store_type     441 non-null    object
#  8   latitude       440 non-null    object
#  9   country_code   441 non-null    object
#  10  continent      441 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 41.6+ KB
# None
#      index                                            address longitude  \
# 0        0                                                NaN       NaN
# 1        1  Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, ...  51.62907
# ...

# %%
######## this cell was wrong is it removed the value 'WEB-1388012W' which was needed ###########

# # Show rows where 'longitude' values are isnull
# filtered_longitude_store_details_df = filtered_store_details_df[filtered_store_details_df['longitude'].isnull()]

# display(filtered_longitude_store_details_df.info())
# display(filtered_longitude_store_details_df)

# %%
# Show rows where 'store_code' values are isnull
filtered_store_code_store_details_df = filtered_store_details_df[filtered_store_details_df['store_code'].isnull()]

display(filtered_store_code_store_details_df.info())
display(filtered_store_code_store_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 217 to 437
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          3 non-null      int64
#  1   address        0 non-null      object
#  2   longitude      0 non-null      object
#  3   locality       0 non-null      object
#  4   store_code     0 non-null      object
#  5   staff_numbers  0 non-null      object
#  6   opening_date   0 non-null      object
#  7   store_type     0 non-null      object
#  8   latitude       0 non-null      object
#  9   country_code   0 non-null      object
#  10  continent      0 non-null      object
# dtypes: int64(1), object(10)
# memory usage: 288.0+ bytes
# None
#      index address longitude locality store_code staff_numbers opening_date  \
# 217    217     NaN       NaN      NaN        NaN           NaN          NaN
# 405    405     NaN       NaN      NaN        NaN           NaN          NaN
# ...

# %%
# Filter and exclude rows where 'store_code' values are isnull i.e. we want notnull rows
filtered_store_details_df = filtered_store_details_df[filtered_store_details_df['store_code'].notnull()]

display(filtered_store_details_df.info())
display(filtered_store_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 441 entries, 0 to 450
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          441 non-null    int64
#  1   address        440 non-null    object
#  2   longitude      440 non-null    object
#  3   locality       440 non-null    object
#  4   store_code     441 non-null    object
#  5   staff_numbers  441 non-null    object
#  6   opening_date   441 non-null    object
#  7   store_type     441 non-null    object
#  8   latitude       440 non-null    object
#  9   country_code   441 non-null    object
#  10  continent      441 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 41.3+ KB
# None
#      index                                            address longitude  \
# 0        0                                                NaN       NaN
# 1        1  Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, ...  51.62907
# ...

# %%
filtered_store_details_df['store_code'] = filtered_store_details_df['store_code'].astype('string')
display(filtered_store_details_df.info())
display(filtered_store_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 441 entries, 0 to 450
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          441 non-null    int64
#  1   address        440 non-null    object
#  2   longitude      440 non-null    object
#  3   locality       440 non-null    object
#  4   store_code     441 non-null    string
#  5   staff_numbers  441 non-null    object
#  6   opening_date   441 non-null    object
#  7   store_type     441 non-null    object
#  8   latitude       440 non-null    object
#  9   country_code   441 non-null    object
#  10  continent      441 non-null    object
# dtypes: int64(1), object(9), string(1)
# memory usage: 41.3+ KB
# None
#      index                                            address longitude  \
# 0        0                                                NaN       NaN
# 1        1  Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, ...  51.62907
# ...

# %%
# # Check for entries that match a numeric pattern
# filtered_store_details_df = filtered_store_details_df[~filtered_store_details_df['store_type'].str.isnumeric()]

# display(filtered_store_details_df.info())
# display(filtered_store_details_df)

# %% [markdown]
# # staff_numbers

# %%
# Check for entries that match a numeric pattern
#isolate numbers that contain other things such as letters
filtered_staff_numbers_store_details_df = filtered_store_details_df[~filtered_store_details_df['staff_numbers'].str.isnumeric()]

display(filtered_staff_numbers_store_details_df.info())
display(filtered_staff_numbers_store_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 31 to 375
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          5 non-null      int64
#  1   address        5 non-null      object
#  2   longitude      5 non-null      object
#  3   locality       5 non-null      object
#  4   store_code     5 non-null      string
#  5   staff_numbers  5 non-null      object
#  6   opening_date   5 non-null      object
#  7   store_type     5 non-null      object
#  8   latitude       5 non-null      object
#  9   country_code   5 non-null      object
#  10  continent      5 non-null      object
# dtypes: int64(1), object(9), string(1)
# memory usage: 480.0+ bytes
# None
#      index                                            address longitude  \
# 31      31  Flat 69\nSuzanne walk\nEast Michelle\nE80 8HS,...  52.68333
# 179    179         Girschnerweg 163\n93597 Angermünde, Dahlem   52.4581
# ...

# %%
# Filter out letters from the 'staff_numbers'
filtered_store_details_df['staff_numbers'] = filtered_store_details_df['staff_numbers'].str.replace(r'[^0-9]', '', regex=True)

# # Change datatype to int64
# filtered_store_details_df['staff_numbers'] = filtered_store_details_df['staff_numbers'].astype('int64')

display(filtered_store_details_df.info())
display(filtered_store_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 441 entries, 0 to 450
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          441 non-null    int64
#  1   address        440 non-null    object
#  2   longitude      440 non-null    object
#  3   locality       440 non-null    object
#  4   store_code     441 non-null    string
#  5   staff_numbers  441 non-null    object
#  6   opening_date   441 non-null    object
#  7   store_type     441 non-null    object
#  8   latitude       440 non-null    object
#  9   country_code   441 non-null    object
#  10  continent      441 non-null    object
# dtypes: int64(1), object(9), string(1)
# memory usage: 41.3+ KB
# None
#      index                                            address longitude  \
# 0        0                                                NaN       NaN
# 1        1  Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, ...  51.62907
# ...

# %%
# Check for entries that match a numeric pattern
#isolate numbers that contain other things such as letters
filtered_staff_numbers_store_details_df = filtered_store_details_df[~filtered_store_details_df['staff_numbers'].str.isnumeric()]

display(filtered_staff_numbers_store_details_df.info())
display(filtered_staff_numbers_store_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          0 non-null      int64
#  1   address        0 non-null      object
#  2   longitude      0 non-null      object
#  3   locality       0 non-null      object
#  4   store_code     0 non-null      string
#  5   staff_numbers  0 non-null      object
#  6   opening_date   0 non-null      object
#  7   store_type     0 non-null      object
#  8   latitude       0 non-null      object
#  9   country_code   0 non-null      object
#  10  continent      0 non-null      object
# dtypes: int64(1), object(9), string(1)
# memory usage: 0.0+ bytes
# None
# Empty DataFrame
# Columns: [index, address, longitude, locality, store_code, staff_numbers, opening_date, store_type, latitude, country_code, continent]
# Index: []

# %% [markdown]
# # store_type

# %%
print(filtered_store_details_df['store_type'].unique())
print(filtered_store_details_df['store_type'].nunique())

# Change datatype to category
filtered_store_details_df['store_type'] = filtered_store_details_df['store_type'].astype('category')
# Out:
# ['Web Portal' 'Local' 'Super Store' 'Mall Kiosk' 'Outlet']
# 5

# %% [markdown]
# # store_code

# %%
# Change datatype to string
filtered_store_details_df['store_code'] = filtered_store_details_df['store_code'].astype('string')

# %% [markdown]
# # coutnry_code

# %%
print(filtered_store_details_df['country_code'].unique())
print(filtered_store_details_df['country_code'].nunique())

# Change datatype to category
filtered_store_details_df['country_code'] = filtered_store_details_df['country_code'].astype('category')
# Out:
# ['GB' 'DE' 'US']
# 3

# %% [markdown]
# # continent

# %%
print(filtered_store_details_df['continent'].unique())
print(filtered_store_details_df['continent'].nunique())
# Out:
# ['Europe' 'America' 'eeEurope' 'eeAmerica']
# 4

# %%
# Replace 'eeEurope': 'Europe', 'eeAmerica': 'America'
filtered_store_details_df['continent'] = filtered_store_details_df['continent'].replace({'eeEurope': 'Europe', 'eeAmerica': 'America'})
filtered_store_details_df['continent'] = filtered_store_details_df['continent'].astype('category')

print(filtered_store_details_df['continent'].unique())
print(filtered_store_details_df['continent'].nunique())
display(filtered_store_details_df)
# Out:
# ['Europe', 'America']
# Categories (2, object): ['America', 'Europe']
# 2
#      index                                            address longitude  \
# 0        0                                                NaN       NaN
# 1        1  Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, ...  51.62907
# 2        2        Heckerstraße 4/5\n50491 Säckingen, Landshut  48.52961
# 3        3  5 Harrison tunnel\nSouth Lydia\nWC9 2BE, Westbury     51.26
# 4        4  Studio 6\nStephen landing\nSouth Simon\nB77 2W...   53.0233
# ..     ...                                                ...       ...
# 445    445  Flat 7\nStephanie lake\nMorrisside\nHP8 8LH, C...  50.76306
# 446    446    Täschestraße 25\n39039 Nördlingen, Kirchlengern      52.2
# 448    448  Studio 8\nMoss mall\nWest Linda\nM0E 6XR, High...  51.62907
# 449    449               Baumplatz 6\n80114 Kötzting, Bretten  49.03685
# 450    450  Gotthilf-Rose-Straße 7/3\n45457 Feuchtwangen, ...  50.64336
#
# ...

# %% [markdown]
# # address

# %%
print(filtered_store_details_df['address'].unique())
print(filtered_store_details_df['address'].nunique())
# Change datatype to string
filtered_store_details_df['address'] = filtered_store_details_df['address'].astype('string')
# Out:
# [nan 'Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, High Wycombe'
#  'Heckerstraße 4/5\n50491 Säckingen, Landshut'
#  '5 Harrison tunnel\nSouth Lydia\nWC9 2BE, Westbury'
#  'Studio 6\nStephen landing\nSouth Simon\nB77 2WA, Belper'
#  'Flat 92u\nChristian harbors\nPort Charlotte\nN57 8FJ, Gainsborough'
#  '7 Gillian rue\nWest Robertside\nPH4 8NY, Rutherglen'
#  'Lilija-Heß-Allee 660\n34566 Regensburg, Stuttgart'
#  '510 Jill Mill\nSouth Laura, FL 38723, Kaukauna'
#  '3 Lee valleys\nWest Janetview\nDY4M 2RL, Hartley'
#  '8 Gareth skyway\nSimmonsview\nSW4 7PL, Rutherglen'
#  'Bergerstr. 1/3\n59183 Seelow, Siegburg'
#  'Flat 37\nBennett expressway\nNew Charlotte\nSY8R 5WE, Devizes'
#  '520 Fisher Inlet Suite 594\nPort Eric, IL 71753, Crystal Lake'
#  'Herma-Rädel-Gasse 29\n74557 Fulda, Halstenbek'
#  '4 Teresa lodge\nWest Mathewchester\nSP39 3UZ, Lancing'
#  '74 Mills route\nLaurahaven\nPL4R 6HA, Newbury'
#  '9 Ryan springs\nLake Allan\nE0 1AW, Lymington'
# ...

# %% [markdown]
# # locality

# %%
print(filtered_store_details_df['locality'].unique())
print(filtered_store_details_df['locality'].nunique())

# Change datatype to string
filtered_store_details_df['locality'] = filtered_store_details_df['locality'].astype('string')
# Out:
# [nan 'High Wycombe' 'Landshut' 'Westbury' 'Belper' 'Gainsborough'
#  'Rutherglen' 'Stuttgart' 'Kaukauna' 'Hartley' 'Siegburg' 'Devizes'
#  'Crystal Lake' 'Halstenbek' 'Lancing' 'Newbury' 'Lymington' 'Chapletown'
#  'Barnet' 'East Dereham' 'Poulton-le-Fylde' 'Bushey' 'Ehingen' 'Aberdeen'
#  'Surbiton' 'Inverness' 'Weimar' 'Penzance' 'Albstadt' 'Hechingen'
#  'Mexborough' 'Arbroath' 'Cowes' 'Clacton-on-Sea' 'Boston'
#  'Charlottenburg-Nord' 'Bretten' 'Sun City Center' 'Karben' 'Martinsburg'
#  'Oschatz' 'Kingston upon Hull' 'Leyland' 'Venice' 'Schleswig' 'Eppingen'
#  'Losheim' 'Burscheid' 'Southsea' 'Porterville' 'Walsrode' 'Exeter'
#  'Thetford' 'Morningside Heights' 'Searcy' 'Radevormwald' 'Stade'
#  'Mira Mesa' 'Strood' 'Verl' 'Wesseling' 'Pfullingen' 'Bensheim'
#  'Walton-on-the-Naze' 'Friedberg' 'Winsford' 'Newburgh' 'Selby'
#  'Oberhausen' 'Zeitz' 'Viewpark' 'Rhosllanerchrugog' 'Marburg an der Lahn'
#  'Waverly' 'Memmingen' 'Trossingen' 'Dahlem' 'Lower Earley' 'Barmbek-Nord'
# ...

# %% [markdown]
# # opening_date

# %%
print(filtered_store_details_df['opening_date'].unique())
print(filtered_store_details_df['opening_date'].nunique())
# Out:
# ['2010-06-12' '1996-10-25' '2013-04-12' '2014-01-02' '2019-09-09'
#  '1995-05-15' '2001-01-04' '2000-06-01' '2022-09-05' '2004-09-11'
#  'October 2012 08' 'July 2015 14' '2014-10-11' '2018-04-05' '1994-03-08'
#  '2020-06-05' '2004-05-02' '2016-02-12' '2008-01-21' '2022-08-01'
#  '1994-08-12' '2010-10-19' '2013-08-05' '2017-12-12' '2002-06-18'
#  '2007-06-24' '2017-11-04' '2008-07-08' '1998-12-23' '2011-03-11'
#  '2010-08-25' '2012-11-09' '2016-10-07' '2018-08-15' '1996-10-02'
#  '2018-06-18' '1995-06-04' '1994-10-18' '2002-07-21' '2013-12-23'
#  '2006-10-04' '1999-07-17' '1998-12-19' '2019-07-28' '2017-10-21'
#  '2020-05-13' '2019-12-24' '2002-04-03' '2009-08-07' '2004-05-23'
#  '2001-07-11' '1998-07-07' '2011-07-07' '2007-02-04' '1993-10-13'
#  '2006-06-16' '2006-02-23' '2019-09-08' '1993-09-03' '2002-01-18'
#  '2009-04-14' '2014-07-16' '2012-05-15' '2006-01-13' '2019-01-11'
#  '1994-05-26' '2015-02-16' '2002-03-30' '2003-04-19' '2017-04-15'
# ...

# %%
display(filtered_store_details_df.info())
display(filtered_store_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 441 entries, 0 to 450
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          441 non-null    int64
#  1   address        440 non-null    string
#  2   longitude      440 non-null    object
#  3   locality       440 non-null    string
#  4   store_code     441 non-null    string
#  5   staff_numbers  441 non-null    object
#  6   opening_date   441 non-null    object
#  7   store_type     441 non-null    category
#  8   latitude       440 non-null    object
#  9   country_code   441 non-null    category
#  10  continent      441 non-null    category
# dtypes: category(3), int64(1), object(4), string(3)
# memory usage: 32.8+ KB
# None
#      index                                            address longitude  \
# 0        0                                               <NA>       NaN
# 1        1  Flat 72W
# Sally isle
# East Deantown
# ...

# %%
filtered_store_details_df['opening_date'] = filtered_store_details_df['opening_date'].apply(parse)
display(filtered_store_details_df.info())
display(filtered_store_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 441 entries, 0 to 450
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          441 non-null    int64
#  1   address        440 non-null    string
#  2   longitude      440 non-null    object
#  3   locality       440 non-null    string
#  4   store_code     441 non-null    string
#  5   staff_numbers  441 non-null    object
#  6   opening_date   441 non-null    datetime64[ns]
#  7   store_type     441 non-null    category
#  8   latitude       440 non-null    object
#  9   country_code   441 non-null    category
#  10  continent      441 non-null    category
# dtypes: category(3), datetime64[ns](1), int64(1), object(3), string(3)
# memory usage: 32.8+ KB
# None
#      index                                            address longitude  \
# 0        0                                               <NA>       NaN
# 1        1  Flat 72W
# Sally isle
# ...

# %%
print(filtered_store_details_df['opening_date'].unique())
print(filtered_store_details_df['opening_date'].nunique())
# Out:
# <DatetimeArray>
# ['2010-06-12 00:00:00', '1996-10-25 00:00:00', '2013-04-12 00:00:00',
#  '2014-01-02 00:00:00', '2019-09-09 00:00:00', '1995-05-15 00:00:00',
#  '2001-01-04 00:00:00', '2000-06-01 00:00:00', '2022-09-05 00:00:00',
#  '2004-09-11 00:00:00',
#  ...
#  '2022-08-20 00:00:00', '2017-01-14 00:00:00', '2020-12-15 00:00:00',
#  '2019-10-30 00:00:00', '2014-06-04 00:00:00', '2008-06-08 00:00:00',
#  '2005-05-12 00:00:00', '1998-05-14 00:00:00', '2020-10-17 00:00:00',
#  '2001-05-12 00:00:00']
# Length: 431, dtype: datetime64[ns]
# 431

# %%
# Convert the 'opening_date' column to datetime format, handling specific formats
# filtered_store_details_df['opening_date'] = pd.to_datetime(filtered_store_details_df['opening_date'], errors='coerce', format='%Y-%m-%d')

filtered_store_details_df['opening_date'] = filtered_store_details_df['opening_date'].combine_first(pd.to_datetime(filtered_store_details_df['opening_date'], errors='coerce', format='%Y %B %d'))

# filtered_store_details_df['opening_date'] = filtered_store_details_df['opening_date'].dt.strftime('%Y-%m-%d')

print(filtered_store_details_df['opening_date'].unique())
print(filtered_store_details_df['opening_date'].nunique())
# Out:
# <DatetimeArray>
# ['2010-06-12 00:00:00', '1996-10-25 00:00:00', '2013-04-12 00:00:00',
#  '2014-01-02 00:00:00', '2019-09-09 00:00:00', '1995-05-15 00:00:00',
#  '2001-01-04 00:00:00', '2000-06-01 00:00:00', '2022-09-05 00:00:00',
#  '2004-09-11 00:00:00',
#  ...
#  '2022-08-20 00:00:00', '2017-01-14 00:00:00', '2020-12-15 00:00:00',
#  '2019-10-30 00:00:00', '2014-06-04 00:00:00', '2008-06-08 00:00:00',
#  '2005-05-12 00:00:00', '1998-05-14 00:00:00', '2020-10-17 00:00:00',
#  '2001-05-12 00:00:00']
# Length: 431, dtype: datetime64[ns]
# 431

# %%
display(filtered_store_details_df.info())
display(filtered_store_details_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 441 entries, 0 to 450
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          441 non-null    int64
#  1   address        440 non-null    string
#  2   longitude      440 non-null    object
#  3   locality       440 non-null    string
#  4   store_code     441 non-null    string
#  5   staff_numbers  441 non-null    object
#  6   opening_date   441 non-null    datetime64[ns]
#  7   store_type     441 non-null    category
#  8   latitude       440 non-null    object
#  9   country_code   441 non-null    category
#  10  continent      441 non-null    category
# dtypes: category(3), datetime64[ns](1), int64(1), object(3), string(3)
# memory usage: 48.9+ KB
# None
#      index                                            address longitude  \
# 0        0                                               <NA>       NaN
# 1        1  Flat 72W
# Sally isle
# ...

# %%
print(filtered_store_details_df['opening_date'].unique())
print(filtered_store_details_df['opening_date'].nunique())
# Out:
# <DatetimeArray>
# ['2010-06-12 00:00:00', '1996-10-25 00:00:00', '2013-04-12 00:00:00',
#  '2014-01-02 00:00:00', '2019-09-09 00:00:00', '1995-05-15 00:00:00',
#  '2001-01-04 00:00:00', '2000-06-01 00:00:00', '2022-09-05 00:00:00',
#  '2004-09-11 00:00:00',
#  ...
#  '2022-08-20 00:00:00', '2017-01-14 00:00:00', '2020-12-15 00:00:00',
#  '2019-10-30 00:00:00', '2014-06-04 00:00:00', '2008-06-08 00:00:00',
#  '2005-05-12 00:00:00', '1998-05-14 00:00:00', '2020-10-17 00:00:00',
#  '2001-05-12 00:00:00']
# Length: 431, dtype: datetime64[ns]
# 431

# %%
# Convert 'expiry_date' to datetime format
filtered_store_details_df['opening_date'] = pd.to_datetime(filtered_store_details_df['opening_date'], format='%y-%m-%d', errors='coerce')
display(filtered_store_details_df.info())
display(filtered_store_details_df)
print(filtered_store_details_df['opening_date'].unique())
print(filtered_store_details_df['opening_date'].nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 441 entries, 0 to 450
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          441 non-null    int64
#  1   address        440 non-null    string
#  2   longitude      440 non-null    object
#  3   locality       440 non-null    string
#  4   store_code     441 non-null    string
#  5   staff_numbers  441 non-null    object
#  6   opening_date   441 non-null    datetime64[ns]
#  7   store_type     441 non-null    category
#  8   latitude       440 non-null    object
#  9   country_code   441 non-null    category
#  10  continent      441 non-null    category
# dtypes: category(3), datetime64[ns](1), int64(1), object(3), string(3)
# memory usage: 48.9+ KB
# None
#      index                                            address longitude  \
# 0        0                                               <NA>       NaN
# 1        1  Flat 72W
# Sally isle
# ...

# %%
display(filtered_store_details_df[['opening_date']])
# Out:
#     opening_date
# 0     2010-06-12
# 1     1996-10-25
# 2     2013-04-12
# 3     2014-01-02
# 4     2019-09-09
# ..           ...
# 445   2008-06-08
# 446   2005-05-12
# 448   1998-05-14
# 449   2020-10-17
# 450   2001-05-12
#
# [441 rows x 1 columns]

# %%
filtered_df = store_details_original[store_details_original['store_code'] == 'WEB-1388012W']

display(filtered_df)
# Out:
#    index address longitude  lat locality    store_code staff_numbers  \
# 0      0     NaN       NaN  NaN      NaN  WEB-1388012W           325
#
#   opening_date  store_type latitude country_code continent
# 0   2010-06-12  Web Portal      NaN           GB    Europe
